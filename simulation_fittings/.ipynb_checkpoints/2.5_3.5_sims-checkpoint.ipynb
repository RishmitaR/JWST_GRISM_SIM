# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
import fsps
from grizli import multifit
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
from grizli.utils import SpectrumTemplate

# %%
def L_nu_per_M(l_aa, lam, z, Av, m_star):
    c = 3E18 # speed of light in angstrom
    lam_0 = lam / (1 + z) # restframe wavelenth in angstrom
    dust = 10**(-0.4*Av)
    return ((lam_0**2)/(c * m_star)) * l_aa * dust * 3.839E33

def F_nu_per_M(l_aa, lam, z, Av, m_star):
    conv = 3.086E24 # conversion of Mpc to cm
    D_l = cosmo.luminosity_distance(z).value # in Mpc
    return (1 + z) * L_nu_per_M(l_aa, lam, z, Av, m_star)  / (4 * np.pi * (D_l*conv)**2)

def F_lam_per_M(l_aa, lam, z, Av, m_star):
    c = 3E18 # speed of light in angstrom
    return (c / lam**2) * F_nu_per_M(l_aa, lam, z, Av, m_star)

# %%
#load the beams
mb_01298 = multifit.MultiBeam('2.5_3.5_updated/ngdeep_01298.beams.fits')
mb_02640 = multifit.MultiBeam('2.5_3.5_updated/ngdeep_02640.beams.fits')
# Out:
# 2024-07-17 11:50:46,951 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.570139 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.742489 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1633622393.456 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:46,966 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.570139 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.742489 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1633622393.456 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:46,975 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:46,980 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
# load_master_fits: /home/raghav/aggieSTAAR/grizli_visual_tool/NGDEEP_NIRISS/2.5_3.5_updated/ngdeep_01298.beams.fits
# 2024-07-17 11:50:47,056 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.257818 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.846576 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1654746751.469 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,070 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.257818 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.846576 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1654746751.469 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,078 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,081 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,151 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.005716 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.718060 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1656888183.366 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,166 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.005716 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.718060 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1656888183.366 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,174 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,177 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#  !! Shift GR150C.F150W.220725.conf along dispersion
#  ! Scale 0th order (B) by an additional x 1.5
# 1 jw02079004002_11101_00001_nis_rate.fits GR150C
# 2 jw02079001001_11101_00001_nis_rate.fits GR150C
# 3 jw02079001001_03101_00002_nis_rate.fits GR150R
# 2024-07-17 11:50:47,242 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.220425 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.573324 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1636481723.588 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,260 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.220425 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.573324 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1636481723.588 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,269 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,273 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,404 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.563610 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.887232 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1610702848.378 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,416 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.563610 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.887232 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1610702848.378 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,425 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,429 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,486 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.634794 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.281937 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1641081005.039 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,500 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.634794 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.281937 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1641081005.039 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,507 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,509 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,563 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.659124 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.930323 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1609654505.656 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,578 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.659124 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.930323 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1609654505.656 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,585 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,590 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
# 4 jw02079004002_03101_00002_nis_rate.fits GR150R
# 5 jw02079001002_05101_00002_nis_rate.fits GR150C
# 6 jw02079004001_05101_00002_nis_rate.fits GR150C
# 2024-07-17 11:50:47,652 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.710715 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.320329 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1640498482.470 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,674 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.710715 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.320329 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1640498482.470 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,680 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,683 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,749 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.368455 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.645344 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1635281419.630 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,770 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.368455 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.645344 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1635281419.630 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,776 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,778 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#  !! Shift GR150R.F150W.220725.conf along dispersion
#  ! Scale 0th order (B) by an additional x 1.5
# 7 jw02079001002_09101_00001_nis_rate.fits GR150R
# 8 jw02079004001_09101_00001_nis_rate.fits GR150R
# 9 jw02079004002_05101_00003_nis_rate.fits GR150C
# 2024-07-17 11:50:47,831 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   104.467261 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.387013 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1622684528.732 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,849 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   104.467261 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.387013 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1622684528.732 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,854 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,858 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,904 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.126450 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.779810 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1655872200.399 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,917 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.126450 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.779810 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1655872200.399 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,923 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,925 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,977 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.560709 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.244286 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1641645431.137 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,991 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.560709 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.244286 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1641645431.137 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:47,996 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:47,998 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,049 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.040948 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.485152 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1637916866.093 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,063 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   109.040948 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.485152 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1637916866.093 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,068 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,069 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#  !! Shift GR150R.F200W.220725.conf along dispersion
# 10 jw02079001003_03101_00001_nis_rate.fits GR150R
# 11 jw02079001001_05101_00003_nis_rate.fits GR150C
# 12 jw02079004001_03101_00003_nis_rate.fits GR150R
# 2024-07-17 11:50:48,116 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.476431 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.847834 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1611659626.321 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,129 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   105.476431 from OBSGEO-[XYZ].
# Set OBSGEO-B to    13.847834 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1611659626.321 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,135 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,138 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,189 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.667436 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.298467 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1640831057.621 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,202 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.667436 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.298467 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1640831057.621 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,208 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,211 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,252 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.930905 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.430610 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1638785704.879 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,265 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/wcs/wcs.py:819: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   108.930905 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.430610 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1638785704.879 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:48,271 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:48,274 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#  !! Shift GR150C.F200W.220725.conf along dispersion
# 13 jw02079004003_05101_00001_nis_rate.fits GR150C
# 14 jw02079001002_03101_00003_nis_rate.fits GR150R
# 15 jw02079004001_05101_00003_nis_rate.fits GR150C
from OBSGEO-[XYZ].
# Set OBSGEO-H to 1654498023.103 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2024-07-17 11:50:57,121 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'FLAM CGS per ELECTRON/S' did not parse as fits unit: At col 0, Unit 'FLAM' not supported by the FITS standard. Did you mean flm? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:57,124 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/astropy/units/core.py:2123: UnitsWarning: 'ELECTRON per PHOTON' did not parse as fits unit: At col 0, Unit 'ELECTRON' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#   warnings.warn(msg, UnitsWarning)
#
# 2024-07-17 11:50:57,168 - stpipe - WARNING - /home/raghav/anaconda3/envs/grizli39/lib/python3.9/site-packages/grizli/multifit.py:1888: RuntimeWarning: divide by zero encountered in divide
#   ivar = 1./(1/b.ivar + (self.sys_err*sciu)**2)
# 50 jw02079004002_03101_00001_nis_rate.fits GR150R
#  !! Shift GR150C.F150W.220725.conf along dispersion
#  ! Scale 0th order (B) by an additional x 1.5
# 51 jw02079004002_11101_00002_nis_rate.fits GR150C
# 52 jw02079001001_11101_00002_nis_rate.fits GR150C

# %%
#2d grism of NGDEEP 01298
Idict = {}

for b in mb_01298.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'R-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'C-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
for b in mb_01298.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'R-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'C-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))

        
stk_115C = sum(np.array(Idict['F115W-GR150C']) * np.array(Idict['F115W-GR150C_err']) )/sum(np.array(Idict['F115W-GR150C_err'])) 
stk_115R = sum(np.array(Idict['F115W-GR150R']) * np.array(Idict['F115W-GR150R_err']) )/sum(np.array(Idict['F115W-GR150R_err'])) 
stk_150C = sum(np.array(Idict['F150W-GR150C']) * np.array(Idict['F150W-GR150C_err']) )/sum(np.array(Idict['F150W-GR150C_err'])) 
stk_150R = sum(np.array(Idict['F150W-GR150R']) * np.array(Idict['F150W-GR150R_err']) )/sum(np.array(Idict['F150W-GR150R_err'])) 
stk_200C = sum(np.array(Idict['F200W-GR150C']) * np.array(Idict['F200W-GR150C_err']) )/sum(np.array(Idict['F200W-GR150C_err'])) 
stk_200R = sum(np.array(Idict['F200W-GR150R']) * np.array(Idict['F200W-GR150R_err']) )/sum(np.array(Idict['F200W-GR150R_err'])) 

from matplotlib.gridspec import GridSpec
import seaborn as sea
gs = GridSpec(2,4, width_ratios = [0.75,1.5,1.7,2], hspace = 0)
plt.figure(figsize= [24,5])
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[3])
ax2 = plt.subplot(gs[2])
ax10 = plt.subplot(gs[4])
ax11 = plt.subplot(gs[5])
ax12 = plt.subplot(gs[6])
ax13 = plt.subplot(gs[7])


ax0.imshow(Idict['C-GR150C'], vmin = -1E-23, vmax = np.max(Idict['C-GR150C']), cmap = 'icefire')
ax0.set_xticks([])
ax0.set_yticks([])

ax1.imshow(stk_115C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_01298.beams[0].beam.twod_axis_labels(mpl_axis=ax1)
ax1.set_yticklabels([])

ax2.imshow(stk_150C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_01298.beams[2].beam.twod_axis_labels(mpl_axis=ax2)
ax2.set_yticklabels([])

ax3.imshow(stk_200C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_01298.beams[4].beam.twod_axis_labels(mpl_axis=ax3)
ax3.set_yticklabels([])  

ax10.imshow(Idict['R-GR150R'], vmin = -1E-23, vmax = np.max(Idict['R-GR150R']), cmap = 'icefire')
ax10.set_xticks([])
ax10.set_yticks([])


ax11.imshow(stk_115R, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_01298.beams[1].beam.twod_axis_labels(mpl_axis=ax11)
ax11.set_yticklabels([])

ax12.imshow(stk_150R, cmap = 'icefire', vmin = -0.1, vmax = 0.5  )
mb_01298.beams[10].beam.twod_axis_labels(mpl_axis=ax12)
ax12.set_yticklabels([])

ax13.imshow(stk_200R, cmap = 'icefire', vmin = -0.1, vmax = 0.5 )
mb_01298.beams[6].beam.twod_axis_labels(mpl_axis=ax13)
ax13.set_yticklabels([])
# Out:
# [Text(0, -20.0, ''),
#  Text(0, 0.0, ''),
#  Text(0, 20.0, ''),
#  Text(0, 40.0, ''),
#  Text(0, 60.0, ''),
#  Text(0, 80.0, '')]

# %%
#2d grism of NGDEEP 02640
Jdict = {}

for b in mb_02640.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Jdict[f'R-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Jdict[f'C-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        print("flooga")
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
for b in mb_02640.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R': 
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Jdict[f'R-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Jdict[f'C-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        print("booga ooga")
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C': 
        Jdict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Jdict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))

        
stk_115C = sum(np.array(Jdict['F115W-GR150C']) * np.array(Jdict['F115W-GR150C_err']) )/sum(np.array(Jdict['F115W-GR150C_err'])) 
stk_115R = sum(np.array(Jdict['F115W-GR150R']) * np.array(Jdict['F115W-GR150R_err']) )/sum(np.array(Jdict['F115W-GR150R_err'])) 
stk_150C = sum(np.array(Jdict['F150W-GR150C']) * np.array(Jdict['F150W-GR150C_err']) )/sum(np.array(Jdict['F150W-GR150C_err'])) 
#stk_150R = sum(np.array(Jdict['F150W-GR150R']) * np.array(Jdict['F150W-GR150R_err']) )/sum(np.array(Jdict['F150W-GR150R_err'])) 
#stk_200C = sum(np.array(Jdict['F200W-GR150C']) * np.array(Jdict['F200W-GR150C_err']) )/sum(np.array(Jdict['F200W-GR150C_err'])) 
#stk_200R = sum(np.array(Jdict['F200W-GR150R']) * np.array(Jdict['F200W-GR150R_err']) )/sum(np.array(Jdict['F200W-GR150R_err'])) 

from matplotlib.gridspec import GridSpec
import seaborn as sea
gs = GridSpec(2,4, width_ratios = [0.75,1.5,1.7,2], hspace = 0)
plt.figure(figsize= [24,5])
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[3])
ax2 = plt.subplot(gs[2])
ax10 = plt.subplot(gs[4])
ax11 = plt.subplot(gs[5])
ax12 = plt.subplot(gs[6])
ax13 = plt.subplot(gs[7])


ax0.imshow(Jdict['C-GR150C'], vmin = -1E-23, vmax = np.max(Jdict['C-GR150C']), cmap = 'icefire')
ax0.set_xticks([])
ax0.set_yticks([])

ax1.imshow(stk_115C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_02640.beams[0].beam.twod_axis_labels(mpl_axis=ax1)
ax1.set_yticklabels([])

ax2.imshow(stk_150C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_02640.beams[2].beam.twod_axis_labels(mpl_axis=ax2)
ax2.set_yticklabels([])

ax3.imshow(stk_200C, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_02640.beams[4].beam.twod_axis_labels(mpl_axis=ax3)
ax3.set_yticklabels([])  

ax10.imshow(Jdict['R-GR150R'], vmin = -1E-23, vmax = np.max(Jdict['R-GR150R']), cmap = 'icefire')
ax10.set_xticks([])
ax10.set_yticks([])


ax11.imshow(stk_115R, cmap = 'icefire', vmin = -0.1,vmax = 0.5 )
mb_02640.beams[1].beam.twod_axis_labels(mpl_axis=ax11)
ax11.set_yticklabels([])

ax12.imshow(stk_150R, cmap = 'icefire', vmin = -0.1, vmax = 0.5  )
mb_02640.beams[10].beam.twod_axis_labels(mpl_axis=ax12)
ax12.set_yticklabels([])

ax13.imshow(stk_200R, cmap = 'icefire', vmin = -0.1, vmax = 0.5 )
mb_02640.beams[6].beam.twod_axis_labels(mpl_axis=ax13)
ax13.set_yticklabels([])
# Out:
# [Text(0, -20.0, ''),
#  Text(0, 0.0, ''),
#  Text(0, 20.0, ''),
#  Text(0, 40.0, ''),
#  Text(0, 60.0, ''),
#  Text(0, 80.0, '')]

# %%
sp = fsps.StellarPopulation(zcontinuous=1,sfh=4, imf_type=1, logzsol=0.0, dust_type=2, dust2=0.0, add_neb_emission=True)
sp.params['cloudy_dust'] = True
sp.params['gas_logu'] = -3
sp.params['add_igm_absorption'] = True
sp.params['add_neb_emission'] = True
sp.params['add_neb_continuum'] = True

# %%
sp.params['tau'] = 0.1

# %%
plt.plot(10**sp.log_age*1e-9,sp.sfr)
plt.xlim(0,6)
plt.xlabel('Age (Gyr)', fontsize = 20)
plt.ylabel('SFR (M$\odot$/yr)', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=16)

# %%
specz = 1
lam, spec = sp.get_spectrum(tage = 4, peraa=True)
flam = F_lam_per_M(spec, lam, specz, 0, sp.stellar_mass)

# %%
plt.plot(lam, flam)
plt.xlim(3000,9000)
plt.xlabel('Wavelength ($\lambda$)', fontsize = 20)
plt.ylabel('F$_\lambda$', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=16)

# %%
#compute grism model of NGDEEP 01298
mb_01298.compute_model(spectrum_1d=[lam*(1+specz), flam/(1+specz)*10**11], is_cgs=True, apply_sensitivity = True)

# %%
scif = []
for b in mb_01298.beams:
    e = b.grism.data['ERR']
    noise = np.random.normal(0, np.percentile(e[~np.isnan(e)], 50)*5, np.shape(b.model))

    b.grism.data['SCI'] = b.model + noise
    b.scif = np.ravel(b.model + noise)
    scif.extend(b.scif)
    b.contam = np.zeros_like(b.contam)
mb_01298.scif = np.array(scif)

# %%
np.percentile(e[~np.isnan(e)], 50)
# Out:
# 0.009369022212922573

# %%
#Another 2D Grism of 01298 (?)

Idict = {}

for b in mb_01298.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'R-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'C-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
for b in mb_01298.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'R-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'C-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))

        
stk_115C = sum(np.array(Idict['F115W-GR150C']) * np.array(Idict['F115W-GR150C_err']) )/sum(np.array(Idict['F115W-GR150C_err'])) 
stk_115R = sum(np.array(Idict['F115W-GR150R']) * np.array(Idict['F115W-GR150R_err']) )/sum(np.array(Idict['F115W-GR150R_err'])) 
stk_150C = sum(np.array(Idict['F150W-GR150C']) * np.array(Idict['F150W-GR150C_err']) )/sum(np.array(Idict['F150W-GR150C_err'])) 
stk_150R = sum(np.array(Idict['F150W-GR150R']) * np.array(Idict['F150W-GR150R_err']) )/sum(np.array(Idict['F150W-GR150R_err'])) 
stk_200C = sum(np.array(Idict['F200W-GR150C']) * np.array(Idict['F200W-GR150C_err']) )/sum(np.array(Idict['F200W-GR150C_err'])) 
stk_200R = sum(np.array(Idict['F200W-GR150R']) * np.array(Idict['F200W-GR150R_err']) )/sum(np.array(Idict['F200W-GR150R_err'])) 

from matplotlib.gridspec import GridSpec
import seaborn as sea
gs = GridSpec(2,4, width_ratios = [0.75,1.5,1.7,2], hspace = 0)
plt.figure(figsize= [24,5])
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[3])
ax2 = plt.subplot(gs[2])
ax10 = plt.subplot(gs[4])
ax11 = plt.subplot(gs[5])
ax12 = plt.subplot(gs[6])
ax13 = plt.subplot(gs[7])


ax0.imshow(Idict['C-GR150C'], vmin = -1E-23, vmax = np.max(Idict['C-GR150C']), cmap = 'icefire')
ax0.set_xticks([])
ax0.set_yticks([])

ax1.imshow(stk_115C, cmap = 'icefire', vmin = -0.1,vmax = 1.2 )
mb_01298.beams[0].beam.twod_axis_labels(mpl_axis=ax1)
ax1.set_yticklabels([])

ax2.imshow(stk_150C, cmap = 'icefire', vmin = -0.1,vmax = 1.2 )
mb_01298.beams[2].beam.twod_axis_labels(mpl_axis=ax2)
ax2.set_yticklabels([])

ax3.imshow(stk_200C, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_01298.beams[4].beam.twod_axis_labels(mpl_axis=ax3)
ax3.set_yticklabels([])  

ax10.imshow(Idict['R-GR150R'], vmin = -1E-23, vmax = np.max(Idict['R-GR150R']), cmap = 'icefire')
ax10.set_xticks([])
ax10.set_yticks([])


ax11.imshow(stk_115R, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_01298.beams[1].beam.twod_axis_labels(mpl_axis=ax11)
ax11.set_yticklabels([])

ax12.imshow(stk_150R, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_01298.beams[10].beam.twod_axis_labels(mpl_axis=ax12)
ax12.set_yticklabels([])

ax13.imshow(stk_200R, cmap = 'icefire', vmin = -0.1, vmax = 1.2 )
mb_01298.beams[6].beam.twod_axis_labels(mpl_axis=ax13)
ax13.set_yticklabels([])
# Out:
# [Text(0, -20.0, ''),
#  Text(0, 0.0, ''),
#  Text(0, 20.0, ''),
#  Text(0, 40.0, ''),
#  Text(0, 60.0, ''),
#  Text(0, 80.0, '')]

# %%
ages = [0.1,0.5,1,2,3,4,5,6]

chi = np.zeros_like(ages)
for i,a in enumerate(ages):
    lam, spec = sp.get_spectrum(tage = a, peraa=True)
    flam = F_lam_per_M(spec, lam, specz, 0, sp.stellar_mass)
    tdict = {'a' : SpectrumTemplate(lam,flam)}
    
    tfit = mb_01298.template_at_z(z=specz, templates=tdict)
    chi[i] = tfit['chi2']/mb_01298.DoF

# %%
plt.plot(ages, np.exp(-chi/2))
plt.xlabel('Ages (Gyr)', fontsize = 20)
plt.ylabel('P(a) (yr$-1$)', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=16)

# %%
#compute grism model of NGDEEP 02640
mb_02640.compute_model(spectrum_1d=[lam*(1+specz), flam/(1+specz)*10**11], is_cgs=True, apply_sensitivity = True)

# %%
scif = []
for b in mb_02640.beams:
    e = b.grism.data['ERR']
    noise = np.random.normal(0, np.percentile(e[~np.isnan(e)], 50)*5, np.shape(b.model))

    b.grism.data['SCI'] = b.model + noise
    b.scif = np.ravel(b.model + noise)
    scif.extend(b.scif)
    b.contam = np.zeros_like(b.contam)
mb_02640.scif = np.array(scif)

# %%
np.percentile(e[~np.isnan(e)], 50)
# Out:
# 0.009237023070454597

# %%
#Another 2D Grism of 01298 (?)

Idict = {}

for b in mb_02640.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'R-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        Idict[f'C-{b.grism.filter}'] = np.zeros(b.beam.sh)
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        print("goop")
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'] = []
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'] = []
        
for b in mb_02640.beams:
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150R':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F115W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150R': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'R-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F150W' and b.grism.filter == 'GR150C':
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
        Idict[f'C-{b.grism.filter}'] += b.beam.direct
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150R': 
        print("floop")
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))
        
    if b.grism.pupil == 'F200W' and b.grism.filter == 'GR150C': 
        Idict[f'{b.grism.pupil}-{b.grism.filter}'].append(b.scif.reshape(b.sh))
        Idict[f'{b.grism.pupil}-{b.grism.filter}_err'].append(np.sqrt(b.ivar))

        
stk_115C = sum(np.array(Idict['F115W-GR150C']) * np.array(Idict['F115W-GR150C_err']) )/sum(np.array(Idict['F115W-GR150C_err'])) 
stk_115R = sum(np.array(Idict['F115W-GR150R']) * np.array(Idict['F115W-GR150R_err']) )/sum(np.array(Idict['F115W-GR150R_err'])) 
stk_150C = sum(np.array(Idict['F150W-GR150C']) * np.array(Idict['F150W-GR150C_err']) )/sum(np.array(Idict['F150W-GR150C_err'])) 
#stk_150R = sum(np.array(Idict['F150W-GR150R']) * np.array(Idict['F150W-GR150R_err']) )/sum(np.array(Idict['F150W-GR150R_err'])) 
#stk_200C = sum(np.array(Idict['F200W-GR150C']) * np.array(Idict['F200W-GR150C_err']) )/sum(np.array(Idict['F200W-GR150C_err'])) 
#stk_200R = sum(np.array(Idict['F200W-GR150R']) * np.array(Idict['F200W-GR150R_err']) )/sum(np.array(Idict['F200W-GR150R_err'])) 

from matplotlib.gridspec import GridSpec
import seaborn as sea
gs = GridSpec(2,4, width_ratios = [0.75,1.5,1.7,2], hspace = 0)
plt.figure(figsize= [24,5])
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[3])
ax2 = plt.subplot(gs[2])
ax10 = plt.subplot(gs[4])
ax11 = plt.subplot(gs[5])
ax12 = plt.subplot(gs[6])
ax13 = plt.subplot(gs[7])


ax0.imshow(Idict['C-GR150C'], vmin = -1E-23, vmax = np.max(Idict['C-GR150C']), cmap = 'icefire')
ax0.set_xticks([])
ax0.set_yticks([])

ax1.imshow(stk_115C, cmap = 'icefire', vmin = -0.1,vmax = 1.2 )
mb_02640.beams[0].beam.twod_axis_labels(mpl_axis=ax1)
ax1.set_yticklabels([])

ax2.imshow(stk_150C, cmap = 'icefire', vmin = -0.1,vmax = 1.2 )
mb_02640.beams[2].beam.twod_axis_labels(mpl_axis=ax2)
ax2.set_yticklabels([])

ax3.imshow(stk_200C, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_02640.beams[4].beam.twod_axis_labels(mpl_axis=ax3)
ax3.set_yticklabels([])  

ax10.imshow(Idict['R-GR150R'], vmin = -1E-23, vmax = np.max(Idict['R-GR150R']), cmap = 'icefire')
ax10.set_xticks([])
ax10.set_yticks([])


ax11.imshow(stk_115R, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_02640.beams[1].beam.twod_axis_labels(mpl_axis=ax11)
ax11.set_yticklabels([])

ax12.imshow(stk_150R, cmap = 'icefire', vmin =- 0.1,vmax = 1.2 )
mb_02640.beams[10].beam.twod_axis_labels(mpl_axis=ax12)
ax12.set_yticklabels([])

ax13.imshow(stk_200R, cmap = 'icefire', vmin = -0.1, vmax = 1.2 )
mb_02640.beams[6].beam.twod_axis_labels(mpl_axis=ax13)
ax13.set_yticklabels([])
# Out:
# [Text(0, -20.0, ''),
#  Text(0, 0.0, ''),
#  Text(0, 20.0, ''),
#  Text(0, 40.0, ''),
#  Text(0, 60.0, ''),
#  Text(0, 80.0, '')]

# %%
ages = [0.1,0.5,1,2,3,4,5,6]

chi = np.zeros_like(ages)
for i,a in enumerate(ages):
    lam, spec = sp.get_spectrum(tage = a, peraa=True)
    flam = F_lam_per_M(spec, lam, specz, 0, sp.stellar_mass)
    tdict = {'a' : SpectrumTemplate(lam,flam)}
    
    tfit = mb_02640.template_at_z(z=specz, templates=tdict)
    chi[i] = tfit['chi2']/mb_02640.DoF

# %%
plt.plot(ages, np.exp(-chi/2))
plt.xlabel('Ages (Gyr)', fontsize = 20)
plt.ylabel('P(a) (yr$-1$)', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=16)
